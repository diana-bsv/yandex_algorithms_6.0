# %%
#1

x1 = int(input())
y1 = int(input())
x2 = int(input())
y2 = int(input())
x = int(input())
y = int(input())

if x > x1:
    if x > x2:
        if y<y1:
            print("SE")
        elif y>y2:
            print("NE")
        else:
            print("E")
            
    elif y > y2:
        print("N")
    else:
        print("S")
    
elif y<y1:
    print("SW")
elif y>y2:
    print("NW")
else:
    print("W")

# %%
#2 

a = int(input())
b = int(input())
c = int(input())
d = int(input())

if not a:
    print(1, c+1)
elif not b:
    print(1,d+1)
    
elif not c:
    print(a+1, 1)
    
elif not d:
    print(b+1, 1)
else:

    one = min(max(a,b), max(c,d)) 

    two = min(a,b) + min(c,d) 

    if (one < two) or ((a>b) and (c<d)) or ((a<b) and (c>d)):
        if max(a,b) < max(c,d):
            print(max(a,b)+1, 1)
        else:
            print(1, max(c,d)+1)

    else:
        print(min(a,b)+1, min(c,d)+1)

# %%
n = int(input())
m = n
arr = []
blank = 1
ans = ''

for i in range(n):
    strr = input()
    
    if blank:
        if strr != "."*n:
            blank = 0
            arr.append(strr)
    else:
        arr.append(strr)
        
if arr == []:
    if not ans: ans = "X"
    
while(arr[-1] == "."*n):
    arr.pop()
    
m = len(arr)
if m == 0:
    if not ans: ans = "X"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      17 ans = ''
#      19 for i in range(n):
# ---> 20     strr = input()
#      22     if blank:
#      23         if strr != "."*n:
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
# ...

# %%
#8
n = 8 
m = 7
arr = ['.####...',
'.#.##...',
'.####...',
'.#.##...',
'.####...',
'.####...',
'.####...']
ans = ''

# %%
n = 6 
m = 5
arr = ['.#.#..',
       '.#.#..',
       '.#.#..',
       '.###..', 
       '.#.#..']
ans = ''

# %%
d = 1
st = 0
en = n-1

for i in range(n):
    for j in range(m):
        if arr[j][i] == "#":
            d = 0
            break
    if d:
        st = i+1
    else:
        break

d=1
        
for i in range(n-1 ,-1, -1):
    for j in range(m):
        if arr[j][i] == "#":
            d = 0
            break
    if d:
        en = i
    else:
        break
        
        
if st >= n:
    if not ans: ans = "X"
    
if en < 0:
    if not ans: ans = "X"
    
for i in range(m):
    arr[i] = arr[i][st:en]
    
n = len(arr[0])

# %%
arr
# Out:
# ['####', '#.##', '####', '#.##', '####', '####', '####']

# %%
if arr == ["#"*n for _ in range(m)]:
    ans = 'I'
    print(1)
    
elif arr[0] == "#"*n:
    #OCP
    print(22)
    
    i = 1
    
    while(arr[i] == "#"*n):
        i += 1
        
    print("3232 ", i)
    line = arr[i]
    
    if line[0] == ".":
        ans = "X"
        print(2)
        
    diff = 0
    prev = "#"
    for x in line:
        if x != prev:
            diff += 1
            prev = x
            
    if diff == 1:
        #C
        while((i<m) and (arr[i] == line)):
            i += 1
        if i == m:
            ans = "X"
            print(3)
            
        elif (arr[i] != "#"*n):
            ans = "X"
            print(4)
        else:
            while((i<m) and (arr[i] == "#"*n)):
                i += 1
            if i == m:
                ans = "C"
                print(5)
            else:
                ans = "X"
                print(6)
        
        
    elif diff == 2:
        #OP
        while((i<m) and (arr[i] == line)):
            i += 1
        if i == m:
            ans = "X"
            print(7)
            
        elif (arr[i] != "#"*n):
            ans = "X"
            print(8)
        
        else:
            while((i<m) and (arr[i] == "#"*n)):
                i += 1
            if i == m:
                ans = "O"
                print(9)
            else:
                newl = arr[i]
                
                if newl[0] != "#":
                    ans = "X"
                    print(10)
                else:
                    
                    diff = 0
                    prev = "#"
                    coord = None
                    for x in range(len(newl)):
                        if newl[x] != prev:
                            diff += 1
                            prev = newl[x]
                            coord = x
                            
                    if diff != 1:
                        ans = "X"
                        print(11)
                    elif line[:coord+1] != newl[:coord+1]:
                        ans = "X"
                        print(12)
                    else:
                        while((i<m) and (arr[i] == newl)):
                            i += 1
                        if i == m:
                            ans = "P"
                            print(13)
                        else:
                            ans = "X"
                            print(14)
        
    else:
        ans = "X"
    
else:
    #LH
    line = arr[0]
    i = 0
    if line[0] == ".":
        ans = "X"
        print(20)
    else:
        diff = 0
        prev = "#"
        
        for x in line:
            if x != prev:
                diff += 1
                prev = x
                
        if diff == 1:
            #L
            while((i<m) and (arr[i] == line)):
                i += 1
            if i == m:
                ans = "X"
                print(23)

            elif (arr[i] != "#"*n):
                ans = "X"
                print(24)
            else:
                while((i<m) and (arr[i] == "#"*n)):
                    i += 1
                if i == m:
                    ans = "L"
                    print(25)
                else:
                    ans = "X"
                    print(26)
            
            
        elif diff == 2:
            #H
            while((i<m) and (arr[i] == line)):
                i += 1
            if i == m:
                ans = "X"
                print(27)

            elif (arr[i] != "#"*n):
                ans = "X"
                print(28)
            else:
                while((i<m) and (arr[i] == "#"*n)):
                    i += 1
                if i == m:
                    ans = "X"
                    print(29)
                else:
                    while((i<m) and (arr[i] == line)):
                        i += 1
                    if i == m:
                        ans = "H"
                        print(30)
                        
                    else:
                        ans = "X"
                    
            
        else:
            ans = "X"
            print(32)
            
                
if ans == -1:
    ans = "X"
    
print(ans)
# Out:
# 22
# 3232  1
# 11
# X

# %%
arr[0][0]

# %%
arr == ["#"*n for _ in range(m)]

# %%
if not ans: ans = "z"

# %%
ans

# %%
ans

# %%
diff = 0
prev = "#"
coord = -1
        
for x in range(len(newl)):
    
    if newl[x] != prev:
        print(x)
        diff += 1
        prev = newl[x]
        coord = x

# %%
#3

n = int(input())
m = n
arr = []
blank = 1
ans = ''

for i in range(n):
    strr = input()
    
    if blank:
        if strr != "."*n:
            blank = 0
            arr.append(strr)
    else:
        arr.append(strr)
        
if arr == []:
    ans = "X"

if not ans:
    while(arr[-1] == "."*n):
        arr.pop()

    m = len(arr)
    if m == 0:
        ans = "X"


    d = 1
    st = 0
    en = n

    for i in range(n):
        for j in range(m):
            if arr[j][i] == "#":
                d = 0
                break
        if d:
            st = i+1
        else:
            break

    d=1

    for i in range(n-1 ,-1, -1):
        for j in range(m):
            if arr[j][i] == "#":
                d = 0
                break
        if d:
            en = i
        else:
            break


    if st >= n:
        if not ans: ans = "X"

    if en < 0:
        if not ans: ans = "X"

    for i in range(m):
        arr[i] = arr[i][st:en]

    n = len(arr[0])


    if not ans:
        if arr == ["#"*n for _ in range(m)]:
            if not ans: ans = 'I'
            #print(1)

        elif arr[0] == "#"*n:
            #OCP
            #print(22)

            i = 1

            while(arr[i] == "#"*n):
                i += 1

        #     print("3232 ", i)
            line = arr[i]

            if line[0] == ".":
                if not ans: ans = "X"
                #print(2)

            diff = 0
            prev = "#"
            for x in line:
                if x != prev:
                    diff += 1
                    prev = x

            if diff == 1:
                #C
                while((i<m) and (arr[i] == line)):
                    i += 1
                if i == m:
                    if not ans: ans = "X"
                    #print(3)

                elif (arr[i] != "#"*n):
                    if not ans: ans = "X"
                    #print(4)
                else:
                    while((i<m) and (arr[i] == "#"*n)):
                        i += 1
                    if i == m:
                        if not ans: ans = "C"
                        #print(5)
                    else:
                        if not ans: ans = "X"
                        #print(6)


            elif diff == 2:
                #OP
                while((i<m) and (arr[i] == line)):
                    i += 1
                if i == m:
                    if not ans: ans = "X"
                    #print(7)

                elif (arr[i] != "#"*n):
                    if not ans: ans = "X"
                    #print(8)

                else:
                    while((i<m) and (arr[i] == "#"*n)):
                        i += 1
                    if i == m:
                        if not ans: ans = "O"
                        #print(9)
                    else:
                        newl = arr[i]

                        if newl[0] != "#":
                            if not ans: ans = "X"
                            #print(10)
                        else:

                            diff = 0
                            prev = "#"
                            coord = None
                            for x in range(len(newl)):
                                if newl[x] != prev:
                                    diff += 1
                                    prev = newl[x]
                                    coord = x

                            if diff != 1:
                                if not ans: ans = "X"
                                #print(11)
                            elif line[:coord+1] != newl[:coord+1]:
                                if not ans: ans = "X"
                                #print(12)
                            else:
                                while((i<m) and (arr[i] == newl)):
                                    i += 1
                                if i == m:
                                    if not ans: ans = "P"
                                    #print(13)
                                else:
                                    if not ans: ans = "X"
                                    #print(14)

            else:
                if not ans: ans = "X"

        else:
            #LH
            line = arr[0]
            i = 0
            if line[0] == ".":
                if not ans: ans = "X"
                #print(20)
            else:
                diff = 0
                prev = "#"

                for x in line:
                    if x != prev:
                        diff += 1
                        prev = x

                if diff == 1:
                    #L
                    while((i<m) and (arr[i] == line)):
                        i += 1
                    if i == m:
                        if not ans: ans = "X"
                        #print(23)

                    elif (arr[i] != "#"*n):
                        if not ans: ans = "X"
                        #print(24)
                    else:
                        while((i<m) and (arr[i] == "#"*n)):
                            i += 1
                        if i == m:
                            if not ans: ans = "L"
                            #print(25)
                        else:
                            if not ans: ans = "X"
                            #print(26)


                elif diff == 2:
                    #H
                    while((i<m) and (arr[i] == line)):
                        i += 1
                    if i == m:
                        if not ans: ans = "X"
                        #print(27)

                    elif (arr[i] != "#"*n):
                        if not ans: ans = "X"
                        #print(28)
                    else:
                        while((i<m) and (arr[i] == "#"*n)):
                            i += 1
                        if i == m:
                            if not ans: ans = "X"
                            #print(29)
                        else:
                            while((i<m) and (arr[i] == line)):
                                i += 1
                            if i == m:
                                if not ans: ans = "H"
                                #print(30)

                            else:
                                if not ans: ans = "X"


                else:
                    if not ans: ans = "X"
                    #print(32)


if not ans:
    ans = "X"
    
print(ans)
# Out:
# 3
# ...
# ...
# ...
# X
